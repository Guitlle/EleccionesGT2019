# %%
import pandas as pd
import numpy as np

# %%
actas = pd.read_csv("compareImgs.output.gz", sep=" ")

# %%
actas.columns = ["mesa", "tipo", "A", "B", "igual", "x1", "x23"]

# %%
actas[(actas.igual == False) & (actas.tipo == 4) & (actas.mesa < 153300) & (actas.B != "bdede1efdd02eec3e5ee34eb555e44227d2bb2f1")
     & (actas.A != "cf0091e1fffaa7779dfd2606b20a260d96ad3e7d")]
# Out:
#         mesa  tipo                                         A  \
# 3          1     4  272ac350934e19014018d82e0a3f67a7ab4917b7
# 11         3     4  e600760abad6ae89b47b241767582847de220541
# 15         4     4  4c96c255edcf0355798368c06c9958731043dfe7
# 19         5     4  a4a234e73113c9c50179e7e46e363e4211e8673a
# 27         7     4  c4f2a1ff53c49998e2b0f4321cfb6e63363e02dd
# 39        10     4  44610118ef8ef0a1f5b4bed2fd989f0e72ae26bd
# 55        14     4  264b0db4e64826cacdee41c5bb48b63310fa31dd
# 59        15     4  7bf1a6833f60d590d97838c1a520d25cb9c057da
# 67        17     4  72a199227ad3c5161999510f071f49cadbac5f5d
# 79        20     4  5b415b76caa6e9a6e5eeae4c64335e40edc57dd7
# 83        21     4  4d1e504830f5361981c1aaeb3291ae25ce9ee82b
# 87        22     4  4cfe619200db7af60db93217a09654786ef812e1
# 95        24     4  60d290bfcf2c7b980b8c909aba2ca828ef3b2677
# 107       27     4  dd6a62aecd8a77f8fba0c372ff38ded236ee8507
# ...
